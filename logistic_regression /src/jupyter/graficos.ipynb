# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/ai/blob/main/logistic_regression%20/src/jupyter/graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráficos

# %%
# !git clone https://github.com/financieras/ai.git
# Out:
# fatal: destination path 'ai' already exists and is not an empty directory.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ai/logistic_regression/datasets/preprocessed_data.csv", index_col=0)
# index_col=0 indica que la primera columna del archivo CSV contiene el índice del DataFrame

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1251 entries, 0 to 1250
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Hogwarts_House             1251 non-null   object
#  1   First_Name                 1251 non-null   object
#  2   Last_Name                  1251 non-null   object
#  3   Birthday                   1251 non-null   object
#  4   Best_Hand                  1251 non-null   int64
#  5   Arithmancy                 1251 non-null   float64
#  6   Astronomy                  1251 non-null   float64
#  7   Herbology                  1251 non-null   float64
#  8   Divination                 1251 non-null   float64
#  9   Muggle_Studies             1251 non-null   float64
#  10  Ancient_Runes              1251 non-null   float64
#  11  History_of_Magic           1251 non-null   float64
#  12  Transfiguration            1251 non-null   float64
#  13  Potions                    1251 non-null   float64
#  14  Care_of_Magical_Creatures  1251 non-null   float64
#  15  Charms                     1251 non-null   float64
#  16  Flying                     1251 non-null   float64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 175.9+ KB

# %%
df.head()   # muestra las cinco primeras filas
# Out:
#       Hogwarts_House First_Name  Last_Name    Birthday  Best_Hand  Arithmancy  \
# Index
# 0          Ravenclaw     Tamara        Hsu  2000-03-30          0     58384.0
# 1          Slytherin      Erich    Paredes  1999-10-14          1     67239.0
# 2          Ravenclaw   Stephany      Braun  1999-11-03          0     23702.0
# 3         Gryffindor      Vesta  Mcmichael  2000-08-19          0     32667.0
# 4          Slytherin    Corrine    Hammond  1999-04-04          1     21209.0
#
#         Astronomy  Herbology  Divination  Muggle_Studies  Ancient_Runes  \
# Index
# 0     -487.886086   5.727180       4.722      272.035831     532.484226
# 1     -552.060507  -5.987446      -5.612     -487.340557     367.760303
# 2     -366.076117   7.725017       6.140      664.893521     602.585284
# 3      697.742809  -6.497214       4.026     -537.001128     523.982133
# 4     -613.687160  -4.289197      -6.592     -440.997704     396.201804
#
#        History_of_Magic  Transfiguration    Potions  \
# Index
# 0              5.231058      1039.788281   3.790369
# 1              4.107170      1058.944592   7.248742
# 2              3.555579      1088.088348   8.728531
# 3             -4.809637       920.391449   0.821911
# 4              5.380286      1052.845164  11.751212
#
#        Care_of_Magical_Creatures     Charms  Flying
# Index
# 0                       0.715939 -232.79405  -26.89
# 1                       0.091674 -252.18425 -113.45
# 2                      -0.515327 -227.34265   30.42
# 3                      -0.014040 -256.84675  200.64
# 4                       1.049894 -247.94549  -34.69

# %%
# @title Hogwarts_House

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Hogwarts_House').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Herbology

from matplotlib import pyplot as plt
df['Herbology'].plot(kind='hist', bins=20, title='Herbology')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Astronomy

from matplotlib import pyplot as plt
df['Astronomy'].plot(kind='hist', bins=20, title='Astronomy')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Arithmancy

from matplotlib import pyplot as plt
df['Arithmancy'].plot(kind='hist', bins=20, title='Arithmancy')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Astronomy vs Herbology

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Astronomy', y='Herbology', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import seaborn as sns
sns.countplot(df['Hogwarts_House'])
# Out:
# <Axes: xlabel='count', ylabel='Hogwarts_House'>
